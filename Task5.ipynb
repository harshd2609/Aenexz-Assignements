# %%
# Applying knn on a Wine_Quality dataset

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier

# %%
df = pd.read_csv('winequalityN.csv')

# %%
df.head(20)
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36           20.70
# 1   white            6.3              0.30         0.34            1.60
# 2   white            8.1              0.28         0.40            6.90
# 3   white            7.2              0.23         0.32            8.50
# 4   white            7.2              0.23         0.32            8.50
# 5   white            8.1              0.28         0.40            6.90
# 6   white            6.2              0.32         0.16            7.00
# 7   white            7.0              0.27         0.36           20.70
# 8   white            6.3              0.30         0.34            1.60
# 9   white            8.1              0.22         0.43            1.50
# 10  white            8.1              0.27         0.41            1.45
# 11  white            8.6              0.23         0.40            4.20
# 12  white            7.9              0.18         0.37            1.20
# 13  white            6.6              0.16         0.40            1.50
# 14  white            8.3              0.42         0.62           19.25
# 15  white            6.6              0.17         0.38            1.50
# 16  white            6.3              0.48         0.04            1.10
# 17  white            NaN              0.66         0.48            1.20
# 18  white            7.4              0.34         0.42            1.10
# 19  white            6.5              0.31         0.14            7.50
#
#     chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0       0.045                 45.0                 170.0   1.0010  3.00
# 1       0.049                 14.0                 132.0   0.9940  3.30
# 2       0.050                 30.0                  97.0   0.9951  3.26
# 3       0.058                 47.0                 186.0   0.9956  3.19
# 4       0.058                 47.0                 186.0   0.9956  3.19
# 5       0.050                 30.0                  97.0   0.9951  3.26
# 6       0.045                 30.0                 136.0   0.9949  3.18
# 7       0.045                 45.0                 170.0   1.0010  3.00
# 8       0.049                 14.0                 132.0   0.9940  3.30
# 9       0.044                 28.0                 129.0   0.9938  3.22
# 10      0.033                 11.0                  63.0   0.9908  2.99
# 11      0.035                 17.0                 109.0   0.9947  3.14
# 12      0.040                 16.0                  75.0   0.9920  3.18
# 13      0.044                 48.0                 143.0   0.9912  3.54
# 14      0.040                 41.0                 172.0   1.0002  2.98
# 15      0.032                 28.0                 112.0   0.9914  3.25
# 16      0.046                 30.0                  99.0   0.9928  3.24
# 17      0.029                 29.0                  75.0   0.9892  3.33
# 18      0.033                 17.0                 171.0   0.9917  3.12
# 19      0.044                 34.0                 133.0   0.9955  3.22
#
#     sulphates  alcohol  quality
# 0        0.45      8.8        6
# 1        0.49      9.5        6
# 2        0.44     10.1        6
# 3        0.40      9.9        6
# 4        0.40      9.9        6
# 5        0.44     10.1        6
# 6        0.47      9.6        6
# 7        0.45      8.8        6
# 8        0.49      9.5        6
# 9        0.45     11.0        6
# 10       0.56     12.0        5
# 11       0.53      9.7        5
# 12       0.63     10.8        5
# 13       0.52     12.4        7
# 14       0.67      9.7        5
# 15       0.55     11.4        7
# 16       0.36      9.6        6
# 17       0.39     12.8        8
# 18       0.53     11.3        6
# 19       0.50      9.5        5

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df['type'] = df['type'].map({'white' : 0 , 'red': 1})

# %%
df
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.0             0.270         0.36            20.7
# 1        0            6.3             0.300         0.34             1.6
# 2        0            8.1             0.280         0.40             6.9
# 3        0            7.2             0.230         0.32             8.5
# 4        0            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6491     1            6.8             0.620         0.08             1.9
# 6492     1            6.2             0.600         0.08             2.0
# 6494     1            6.3             0.510         0.13             2.3
# 6495     1            5.9             0.645         0.12             2.0
# 6496     1            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6491      0.068                 28.0                  38.0  0.99651  3.42
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6491       0.82      9.5        6
# 6492       0.58     10.5        5
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6463 rows x 13 columns]

# %%
df['quality_label'] = (df['quality'] >= 6).astype(int)

# %%
df
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.0             0.270         0.36            20.7
# 1        0            6.3             0.300         0.34             1.6
# 2        0            8.1             0.280         0.40             6.9
# 3        0            7.2             0.230         0.32             8.5
# 4        0            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6491     1            6.8             0.620         0.08             1.9
# 6492     1            6.2             0.600         0.08             2.0
# 6494     1            6.3             0.510         0.13             2.3
# 6495     1            5.9             0.645         0.12             2.0
# 6496     1            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6491      0.068                 28.0                  38.0  0.99651  3.42
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality  quality_label
# 0          0.45      8.8        6              1
# 1          0.49      9.5        6              1
# 2          0.44     10.1        6              1
# 3          0.40      9.9        6              1
# 4          0.40      9.9        6              1
# ...         ...      ...      ...            ...
# 6491       0.82      9.5        6              1
# 6492       0.58     10.5        5              0
# 6494       0.75     11.0        6              1
# 6495       0.71     10.2        5              0
# 6496       0.66     11.0        6              1
#
# [6463 rows x 14 columns]

# %%
x = df.drop(['quality' , 'quality_label'] , axis = 1)
y = df['quality_label']

# %%
x
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        0            7.0             0.270         0.36            20.7
# 1        0            6.3             0.300         0.34             1.6
# 2        0            8.1             0.280         0.40             6.9
# 3        0            7.2             0.230         0.32             8.5
# 4        0            7.2             0.230         0.32             8.5
# ...    ...            ...               ...          ...             ...
# 6491     1            6.8             0.620         0.08             1.9
# 6492     1            6.2             0.600         0.08             2.0
# 6494     1            6.3             0.510         0.13             2.3
# 6495     1            5.9             0.645         0.12             2.0
# 6496     1            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6491      0.068                 28.0                  38.0  0.99651  3.42
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol
# 0          0.45      8.8
# 1          0.49      9.5
# 2          0.44     10.1
# 3          0.40      9.9
# 4          0.40      9.9
# ...         ...      ...
# 6491       0.82      9.5
# 6492       0.58     10.5
# 6494       0.75     11.0
# 6495       0.71     10.2
# 6496       0.66     11.0
#
# [6463 rows x 12 columns]

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6491    1
# 6492    0
# 6494    1
# 6495    0
# 6496    1
# Name: quality_label, Length: 6463, dtype: int64

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 42)

# %%
x_train
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 459      0            6.1              0.43         0.35             9.1
# 1460     0            8.5              0.17         0.74             3.6
# 4403     0            5.2              0.22         0.46             6.2
# 3828     0            6.3              0.40         0.24             5.1
# 4317     0            6.7              0.34         0.26             1.9
# ...    ...            ...               ...          ...             ...
# 3798     0            7.9              0.21         0.39             2.0
# 5219     1            9.3              0.61         0.26             3.4
# 5254     1           11.5              0.41         0.52             3.0
# 5418     1            9.8              0.25         0.49             2.7
# 881      0            8.8              0.36         0.44             1.9
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 459       0.059                 83.0                 249.0  0.99710  3.37
# 1460      0.050                 29.0                 128.0  0.99280  3.28
# 4403      0.066                 41.0                 187.0  0.99362  3.19
# 3828      0.036                 43.0                 131.0  0.99186  3.24
# 4317      0.038                 58.0                 138.0  0.98930  3.00
# ...         ...                  ...                   ...      ...   ...
# 3798      0.057                 21.0                 138.0  0.99176  3.05
# 5219      0.090                 25.0                  87.0  0.99975  3.24
# 5254      0.080                 29.0                  55.0  1.00010  3.26
# 5418      0.088                 15.0                  33.0  0.99820  3.42
# 881       0.040                  9.0                 121.0  0.99530  3.19
#
#       sulphates    alcohol
# 459        0.50   8.500000
# 1460       0.40  12.400000
# 4403       0.42   9.733333
# 3828       0.44  11.300000
# 4317       0.47  12.200000
# ...         ...        ...
# 3798       0.52  10.900000
# 5219       0.62   9.700000
# 5254       0.88  11.000000
# 5418       0.90  10.000000
# 881        0.48   9.900000
#
# [5170 rows x 12 columns]

# %%
x_test
# Out:
#       type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1143     0            7.2             0.240         0.30             1.6
# 2708     0            6.8             0.230         0.42             7.4
# 4943     1            4.6             0.520         0.15             2.1
# 4194     0            6.7             0.200         0.24             6.5
# 5956     1            9.9             0.530         0.57             2.4
# ...    ...            ...               ...          ...             ...
# 898      0            6.6             0.260         0.29             1.4
# 4649     0            5.7             0.695         0.06             6.8
# 6058     1           10.6             0.360         0.57             2.3
# 304      0            7.3             0.410         0.24             6.8
# 4927     1            7.8             0.645         0.00             2.0
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 1143      0.048                 27.0                 131.0  0.99330  3.25
# 2708      0.044                 56.0                 189.0  0.99580  3.22
# 4943      0.054                  8.0                  65.0  0.99340  3.90
# 4194      0.044                 28.0                 100.0  0.99348  3.12
# 5956      0.093                 30.0                  52.0  0.99710  3.19
# ...         ...                  ...                   ...      ...   ...
# 898       0.039                 13.0                  67.0  0.99150  3.05
# 4649      0.042                  9.0                  84.0  0.99432  3.44
# 6058      0.087                  6.0                  20.0  0.99676  3.14
# 304       0.057                 41.0                 163.0  0.99490  3.20
# 4927      0.082                  8.0                  16.0  0.99640  3.38
#
#       sulphates  alcohol
# 1143       0.45     10.5
# 2708       0.48      9.3
# 4943       0.56     13.1
# 4194       0.33     10.2
# 5956       0.76     11.6
# ...         ...      ...
# 898        0.49     10.9
# 4649       0.44     10.2
# 6058       0.72     11.1
# 304        0.41      9.9
# 4927       0.59      9.8
#
# [1293 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
k = 5
knn = KNeighborsClassifier(n_neighbors = k)

# %%
knn.fit(x_train , y_train )
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0, 1, ..., 1, 0, 0])

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7540603248259861

# %%
print(metrics.confusion_matrix(y_test, y_pred))
# Out:
# [[291 191]
#  [127 684]]

# %%
print(metrics.classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.60      0.65       482
#            1       0.78      0.84      0.81       811
#
#     accuracy                           0.75      1293
#    macro avg       0.74      0.72      0.73      1293
# weighted avg       0.75      0.75      0.75      1293
